# %%
import geopandas as gp

# %%
historic = gp.read_file('./geo_data/Historic_Sites.geojson')

# %%
historic.head()
# Out:
#    OBJECTID  GIS_ID                 GIS_FeatureKey  \
# 0       112       1                    Eldon House
# 1       113       2     Lawson Archaeological Site
# 2       114       3  Museum of Ontario Archaeology
# 3       115       4                Grosvenor Lodge
# 4       116       5   Elsie Perrin Williams Estate
#
#          CulturalResourceCategory  NAICSCde                     NAICSDef  \
# 0  Cultural Spaces and Facilities    712119                Other Museums
# 1               Cultural Heritage    712120  Historic and Heritage Sites
# 2  Cultural Spaces and Facilities    712115  History and Science Museums
# 3               Cultural Heritage    712120  Historic and Heritage Sites
# 4               Cultural Heritage    712120  Historic and Heritage Sites
#
#                                          Description  \
# 0  175 ?year old historic home at the heart of Lo...
# 1  Village site occupied by the Neutral Iroquoian...
# ...
